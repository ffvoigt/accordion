# %%
import napari

# %%
set PYTHONUTF8=1
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\.conda\envs\eventcam1\lib\site-packages\IPython\core\compilerop.py:86, in CachingCompiler.ast_parse(self, source, filename, symbol)
#      81 def ast_parse(self, source, filename='<unknown>', symbol='exec'):
#      82     """Parse code to an AST with the current compiler flags active.
#      83
#      84     Arguments are exactly the same as ast.parse (in the standard library),
#      85     and are passed to the built-in compile function."""
# ---> 86     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
# SyntaxError: invalid syntax (1946385539.py, line 1)

# %%
viewer = napari.Viewer()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 viewer = napari.Viewer()
#
# File ~\.conda\envs\eventcam1\lib\site-packages\napari\_lazy.py:48, in install_lazy.<locals>.__getattr__(name)
#      46 elif name in attr_to_modules:
#      47     try:
# ---> 48         submod = import_module(
#      49             f'{module_name}.{attr_to_modules[name]}'
#      50         )
#      51     except AttributeError as er:
#      52         # if we want any useful error message to show
#      53         # (besides just "cannot import name...") then we need raise anything
#      54         # BUT an attribute error here, because the __getattr__ protocol will
#      55         # swallow that error.
#      56         raise ImportError(
#      57             f'Failed to import {attr_to_modules[name]} from {module_name}. '
#      58             'See cause above'
# ...
